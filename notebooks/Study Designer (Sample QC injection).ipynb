# %% [markdown]
# # Study Designer Example (Sample QC injection)

# %%
from ipywidgets import (RadioButtons, VBox, HBox, Layout, Label, Checkbox, Text, IntSlider)
from qgrid import show_grid
label_layout = Layout(width='100%')
from isatools.create.models import *
from isatools.model import Investigation
from isatools.isatab import dump_tables_to_dataframes as dumpdf
import qgrid
qgrid.nbinstall(overwrite=True)

# %% [markdown]
# ## Sample planning section

# %% [markdown]
# ### Study design type
#
# Please specify if the study is an intervention or an observation.

# %%
rad_study_design = RadioButtons(options=['Intervention', 'Observation'], value='Intervention', disabled=False)
VBox([Label('Study design type?', layout=label_layout), rad_study_design])

# %% [markdown]
# ### Intervention study
#
# If specifying an intervention study, please answer the following:
#  - Are study subjects exposed to a single intervention or to multiple intervention?
#  - Are there 'hard to change' factors, which restrict randomization of experimental unit?
#
# *Note: if you chose 'observation' as the study design type, the following choices will be disabled and you should skip to the Observation study section*

# %%
if rad_study_design.value == 'Intervention':
    study_design = InterventionStudyDesign()
if rad_study_design.value == 'Observation':
    study_design = None
intervention_ui_disabled = not isinstance(study_design, InterventionStudyDesign)
intervention_type = RadioButtons(options=['single', 'multiple'], value='single', disabled=intervention_ui_disabled)
intervention_type_vbox = VBox([Label('Single intervention or to multiple intervention?', layout=label_layout), intervention_type])
free_or_restricted_design = RadioButtons(options=['yes', 'no'], value='no', disabled=intervention_ui_disabled)
free_or_restricted_design_vbox = VBox([Label("Are there 'hard to change' factors?", layout=label_layout), free_or_restricted_design])
HBox([intervention_type_vbox, free_or_restricted_design_vbox])

# %%
hard_to_change_factors_ui_disabled = free_or_restricted_design.value == 'no'
hard_to_change_factors = RadioButtons(options=[1, 2], value=1, disabled=hard_to_change_factors_ui_disabled)
VBox([Label("If applicable, how many 'hard to change factors'?", layout=label_layout), hard_to_change_factors])

# %%
repeats = intervention_type.value != 'single'
factorial_design = free_or_restricted_design.value == 'no'
split_plot_design = (free_or_restricted_design.value == 'yes' and hard_to_change_factors.value == 1)
split_split_plot_design = (free_or_restricted_design.value == 'yes' and hard_to_change_factors.value == 2)
print('Interventions: {}'.format('Multiple interventions' if repeats else 'Single intervention'))
design_type = 'factorial'  # always default to factorial
if split_plot_design:
    design_type = 'split plot'
elif split_split_plot_design:
    design_type = 'split split'
print('Design type: {}'.format(design_type))
# Out:
# Interventions: Single intervention
# Design type: factorial

# %% [markdown]
# #### Factorial design - intervention types
#
# If specifying an factorial design, please list the intervention types here.

# %%
factorial_design_ui_disabled = not factorial_design
chemical_intervention = Checkbox(value=True, description='Chemical intervention', disabled=factorial_design_ui_disabled)
behavioural_intervention = Checkbox(value=False, description='Behavioural intervention', disabled=factorial_design_ui_disabled)
surgical_intervention = Checkbox(value=False, description='Surgical intervention', disabled=factorial_design_ui_disabled)
biological_intervention = Checkbox(value=False, description='Biological intervention', disabled=factorial_design_ui_disabled)
radiological_intervention = Checkbox(value=False, description='Radiological intervention', disabled=factorial_design_ui_disabled)
VBox([chemical_intervention, surgical_intervention, biological_intervention, radiological_intervention])

# %%
level_uis = []
if chemical_intervention:
    agent_levels = Text(
        value='calpol, no agent',
        placeholder='e.g. cocaine, calpol',
        description='Agent:',
        disabled=False
    )
    dose_levels = Text(
        value='low, high',
        placeholder='e.g. low, high',
        description='Dose levels:',
        disabled=False
    )
    duration_of_exposure_levels = Text(
        value='short, long',
        placeholder='e.g. short, long',
        description='Duration of exposure:',
        disabled=False
    )
VBox([Label("Chemical intervention factor levels:", layout=label_layout), agent_levels, dose_levels, duration_of_exposure_levels])

# %%
factory = TreatmentFactory(intervention_type=INTERVENTIONS['CHEMICAL'], factors=BASE_FACTORS)
for agent_level in agent_levels.value.split(','):
    factory.add_factor_value(BASE_FACTORS[0], agent_level.strip())
for dose_level in dose_levels.value.split(','):
    factory.add_factor_value(BASE_FACTORS[1], dose_level.strip())
for duration_of_exposure_level in duration_of_exposure_levels.value.split(','):
    factory.add_factor_value(BASE_FACTORS[2], duration_of_exposure_level.strip())
print('Number of study groups (treatment groups): {}'.format(len(factory.compute_full_factorial_design())))
treatment_sequence = TreatmentSequence(ranked_treatments=factory.compute_full_factorial_design())
# Out:
# Number of study groups (treatment groups): 8

# %% [markdown]
# Next, specify if all study groups of the same size, i.e have the same number of subjects? (in other words, are the groups balanced).

# %%
group_blanced = RadioButtons(options=['Balanced', 'Unbalanced'], value='Balanced', disabled=False)
VBox([Label('Are study groups balanced?', layout=label_layout), group_blanced])

# %% [markdown]
# Provide the number of subject per study group:

# %%
group_size = IntSlider(value=5, min=0, max=100, step=1, description='Group size:', disabled=False, continuous_update=False, orientation='horizontal', readout=True, readout_format='d')
group_size

# %%
plan = SampleAssayPlan(group_size=group_size.value)

# %%
rad_sample_type = RadioButtons(options=['Blood', 'Sweat', 'Tears', 'Urine'], value='Blood', disabled=False)
VBox([Label('Sample type?', layout=label_layout), rad_sample_type])

# %% [markdown]
# How many times each of the samples have been collected?

# %%
sampling_size = IntSlider(value=3, min=0, max=100, step=1, description='Sample size:', disabled=False, continuous_update=False, orientation='horizontal', readout=True, readout_format='d')
sampling_size

# %%
inject_qc_material = Text(
        value='solvent blank',
        placeholder='e.g. blank, water, solvent',
        description='Material:',
        disabled=False
    )
inject_qc_interval = IntSlider(value=10, min=0, max=10, step=1, description='Injection interval:', disabled=False, continuous_update=False, orientation='horizontal', readout=True, readout_format='d')
VBox([inject_qc_material, inject_qc_interval])

# %%
plan.add_sample_type(rad_sample_type.value)
plan.add_sample_plan_record(rad_sample_type.value, sampling_size.value)
plan.add_sample_qc_plan_record(inject_qc_material.value, inject_qc_interval.value)
plan.add_sample_qc_plan_record('reference material', 5)
isa_object_factory = IsaModelObjectFactory(plan, treatment_sequence)

# %% [markdown]
# ## Generate ISA model objects from the sample plan and render the study-sample table

# %% [markdown]
# *Check state of the Sample Assay Plan after entering sample QC information:*

# %%
import json
from isatools.create.models import SampleAssayPlanEncoder
print(json.dumps(plan, cls=SampleAssayPlanEncoder, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "assay_plan": [],
#     "assay_types": [],
#     "group_size": 5,
#     "sample_plan": [
#         {
#             "sample_type": "Blood",
#             "sampling_size": 3
#         }
#     ],
#     "sample_qc_plan": [
#         {
#             "injection_interval": 10,
#             "sample_type": "solvent blank"
#         },
#         {
#             "injection_interval": 5,
#             "sample_type": "reference material"
#         }
#     ],
#     "sample_types": [
#         "Blood"
#     ]
# }

# %%
isa_investigation = Investigation(identifier='inv101')
isa_study = isa_object_factory.create_study_from_plan()
isa_study.filename = 's_study.txt'
isa_investigation.studies = [isa_study]
dataframes = dumpdf(isa_investigation)
sample_table = next(iter(dataframes.values()))
sample_table
# Out:
# INFO:isatools.isatab:Found 156 paths!
# INFO:isatools.isatab:Rendered 156 paths
# INFO:isatools.isatab:Writing 156 rows
#                                            Source Name       Material Type  \
# 0    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 1    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 2    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 3    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...  reference material
# 4    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 5    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 6    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 7    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...  reference material
# 8    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...       solvent blank
# 9    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 10   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 11   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 12   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 13   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 14   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 15   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...  reference material
# 16   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 17   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 18   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...            specimen
# 19   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 20   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 21   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 22   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...  reference material
# 23   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 24   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 25   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 26   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...  reference material
# 27   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...       solvent blank
# 28   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# 29   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...            specimen
# ..                                                 ...                 ...
# 126  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 127  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 128  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 129  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 130  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 131  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 132  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...  reference material
# 133  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 134  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 135  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...            specimen
# 136  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 137  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 138  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 139  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...  reference material
# 140  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...       solvent blank
# 141  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 142  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 143  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 144  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...  reference material
# 145  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 146  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 147  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 148  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 149  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 150  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 151  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...  reference material
# 152  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...       solvent blank
# 153  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 154  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
# 155  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...            specimen
#
#           Protocol REF                        Date Performer  \
# 0    sample collection                  2017-10-20     Frank
# 1    sample collection                  2017-10-20     Frank
# 2    sample collection                  2017-10-20     Frank
# 3    sample collection  2017-10-20T15:32:43.683076     Frank
# 4    sample collection                  2017-10-20     Frank
# 5    sample collection                  2017-10-20     Frank
# 6    sample collection                  2017-10-20     Frank
# 7    sample collection  2017-10-20T15:32:43.683453     Frank
# 8    sample collection  2017-10-20T15:32:43.683406     Frank
# 9    sample collection                  2017-10-20     Frank
# 10   sample collection                  2017-10-20     Frank
# 11   sample collection                  2017-10-20     Frank
# 12   sample collection                  2017-10-20     Frank
# 13   sample collection                  2017-10-20     Frank
# 14   sample collection                  2017-10-20     Frank
# 15   sample collection  2017-10-20T15:32:43.683777     Frank
# 16   sample collection                  2017-10-20     Frank
# 17   sample collection                  2017-10-20     Frank
# 18   sample collection                  2017-10-20     Frank
# 19   sample collection                  2017-10-20     Frank
# 20   sample collection                  2017-10-20     Frank
# 21   sample collection                  2017-10-20     Frank
# 22   sample collection  2017-10-20T15:32:43.691839     Frank
# 23   sample collection                  2017-10-20     Frank
# 24   sample collection                  2017-10-20     Frank
# 25   sample collection                  2017-10-20     Frank
# 26   sample collection  2017-10-20T15:32:43.692416     Frank
# 27   sample collection  2017-10-20T15:32:43.692371     Frank
# 28   sample collection                  2017-10-20     Frank
# 29   sample collection                  2017-10-20     Frank
# ..                 ...                         ...       ...
# 126  sample collection                  2017-10-20     Frank
# 127  sample collection                  2017-10-20     Frank
# 128  sample collection                  2017-10-20     Frank
# 129  sample collection                  2017-10-20     Frank
# 130  sample collection                  2017-10-20     Frank
# 131  sample collection                  2017-10-20     Frank
# 132  sample collection  2017-10-20T15:32:43.690292     Frank
# 133  sample collection                  2017-10-20     Frank
# 134  sample collection                  2017-10-20     Frank
# 135  sample collection                  2017-10-20     Frank
# 136  sample collection                  2017-10-20     Frank
# 137  sample collection                  2017-10-20     Frank
# 138  sample collection                  2017-10-20     Frank
# 139  sample collection  2017-10-20T15:32:43.674379     Frank
# 140  sample collection  2017-10-20T15:32:43.674242     Frank
# 141  sample collection                  2017-10-20     Frank
# 142  sample collection                  2017-10-20     Frank
# 143  sample collection                  2017-10-20     Frank
# 144  sample collection  2017-10-20T15:32:43.675318     Frank
# 145  sample collection                  2017-10-20     Frank
# 146  sample collection                  2017-10-20     Frank
# 147  sample collection                  2017-10-20     Frank
# 148  sample collection                  2017-10-20     Frank
# 149  sample collection                  2017-10-20     Frank
# 150  sample collection                  2017-10-20     Frank
# 151  sample collection  2017-10-20T15:32:43.676543     Frank
# 152  sample collection  2017-10-20T15:32:43.676400     Frank
# 153  sample collection                  2017-10-20     Frank
# 154  sample collection                  2017-10-20     Frank
# 155  sample collection                  2017-10-20     Frank
#
#     Parameter Value[Run Order]  \
# 0                           46
# 1                           48
# 2                           47
# 3                           45
# 4                           51
# 5                           50
# 6                           49
# 7                           50
# 8                           50
# 9                           54
# 10                          53
# 11                          52
# 12                          55
# 13                          56
# 14                          57
# 15                          55
# 16                          59
# 17                          58
# 18                          60
# 19                         108
# 20                         107
# 21                         106
# 22                         105
# 23                         111
# 24                         109
# 25                         110
# 26                         110
# 27                         110
# 28                         112
# 29                         113
# ..                         ...
# 126                         83
# 127                         82
# 128                         84
# 129                         86
# 130                         87
# 131                         85
# 132                         85
# 133                         88
# 134                         90
# 135                         89
# 136                          3
# 137                          2
# 138                          1
# 139                          0
# 140                          0
# 141                          4
# 142                          6
# 143                          5
# 144                          5
# 145                          8
# 146                          9
# 147                          7
# 148                         10
# 149                         12
# 150                         11
# 151                         10
# 152                         10
# 153                         15
# 154                         14
# 155                         13
#
#                                            Sample Name  \
# 0    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 1    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 2    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 3    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 4    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 5    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 6    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 7    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 8    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 9    studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 10   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 11   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 12   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 13   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 14   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 15   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 16   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 17   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 18   studygroup_0eb8ae8e-2651-4cfa-85aa-3bef13cd237...
# 19   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 20   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 21   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 22   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 23   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 24   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 25   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 26   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 27   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 28   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# 29   studygroup_60121793-c35a-442f-aa0e-45aa559f11c...
# ..                                                 ...
# 126  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 127  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 128  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 129  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 130  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 131  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 132  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 133  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 134  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 135  studygroup_fe74f542-2e4b-4a69-83d2-d02c07fbf0d...
# 136  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 137  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 138  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 139  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 140  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 141  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 142  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 143  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 144  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 145  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 146  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 147  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 148  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 149  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 150  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 151  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 152  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 153  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 154  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
# 155  studygroup_ff319696-95e8-4de4-a6d1-43be009ec74...
#
#     Characteristics[organism part]  \
# 0                            Blood
# 1                            Blood
# 2                            Blood
# 3
# 4                            Blood
# 5                            Blood
# 6                            Blood
# 7
# 8
# 9                            Blood
# 10                           Blood
# 11                           Blood
# 12                           Blood
# 13                           Blood
# 14                           Blood
# 15
# 16                           Blood
# 17                           Blood
# 18                           Blood
# 19                           Blood
# 20                           Blood
# 21                           Blood
# 22
# 23                           Blood
# 24                           Blood
# 25                           Blood
# 26
# 27
# 28                           Blood
# 29                           Blood
# ..                             ...
# 126                          Blood
# 127                          Blood
# 128                          Blood
# 129                          Blood
# 130                          Blood
# 131                          Blood
# 132
# 133                          Blood
# 134                          Blood
# 135                          Blood
# 136                          Blood
# 137                          Blood
# 138                          Blood
# 139
# 140
# 141                          Blood
# 142                          Blood
# 143                          Blood
# 144
# 145                          Blood
# 146                          Blood
# 147                          Blood
# 148                          Blood
# 149                          Blood
# 150                          Blood
# 151
# 152
# 153                          Blood
# 154                          Blood
# 155                          Blood
#
#     Characteristics[collection_event_rank_characteristic] Factor Value[AGENT]  \
# 0                                                  1.0               no agent
# 1                                                  1.0               no agent
# 2                                                  1.0               no agent
# 3
# 4                                                  1.0               no agent
# 5                                                  1.0               no agent
# 6                                                  1.0               no agent
# 7
# 8
# 9                                                  1.0               no agent
# 10                                                 1.0               no agent
# 11                                                 1.0               no agent
# 12                                                 1.0               no agent
# 13                                                 1.0               no agent
# 14                                                 1.0               no agent
# 15
# 16                                                 1.0               no agent
# 17                                                 1.0               no agent
# 18                                                 1.0               no agent
# 19                                                 1.0               no agent
# 20                                                 1.0               no agent
# 21                                                 1.0               no agent
# 22
# 23                                                 1.0               no agent
# 24                                                 1.0               no agent
# 25                                                 1.0               no agent
# 26
# 27
# 28                                                 1.0               no agent
# 29                                                 1.0               no agent
# ..                                                 ...                    ...
# 126                                                1.0               no agent
# 127                                                1.0               no agent
# 128                                                1.0               no agent
# 129                                                1.0               no agent
# 130                                                1.0               no agent
# 131                                                1.0               no agent
# 132
# 133                                                1.0               no agent
# 134                                                1.0               no agent
# 135                                                1.0               no agent
# 136                                                1.0                 calpol
# 137                                                1.0                 calpol
# 138                                                1.0                 calpol
# 139
# 140
# 141                                                1.0                 calpol
# 142                                                1.0                 calpol
# 143                                                1.0                 calpol
# 144
# 145                                                1.0                 calpol
# 146                                                1.0                 calpol
# 147                                                1.0                 calpol
# 148                                                1.0                 calpol
# 149                                                1.0                 calpol
# 150                                                1.0                 calpol
# 151
# 152
# 153                                                1.0                 calpol
# 154                                                1.0                 calpol
# 155                                                1.0                 calpol
#
#     Factor Value[INTENSITY] Factor Value[DURATION]
# 0                      high                  short
# 1                      high                  short
# 2                      high                  short
# 3
# 4                      high                  short
# 5                      high                  short
# 6                      high                  short
# 7
# 8
# 9                      high                  short
# 10                     high                  short
# 11                     high                  short
# 12                     high                  short
# 13                     high                  short
# 14                     high                  short
# 15
# 16                     high                  short
# 17                     high                  short
# 18                     high                  short
# 19                      low                   long
# 20                      low                   long
# 21                      low                   long
# 22
# 23                      low                   long
# 24                      low                   long
# 25                      low                   long
# 26
# 27
# 28                      low                   long
# 29                      low                   long
# ..                      ...                    ...
# 126                    high                   long
# 127                    high                   long
# 128                    high                   long
# 129                    high                   long
# 130                    high                   long
# 131                    high                   long
# 132
# 133                    high                   long
# 134                    high                   long
# 135                    high                   long
# 136                     low                  short
# 137                     low                  short
# 138                     low                  short
# 139
# 140
# 141                     low                  short
# 142                     low                  short
# 143                     low                  short
# 144
# 145                     low                  short
# 146                     low                  short
# 147                     low                  short
# 148                     low                  short
# 149                     low                  short
# 150                     low                  short
# 151
# 152
# 153                     low                  short
# 154                     low                  short
# 155                     low                  short
#
# [156 rows x 12 columns]

# %%
print('Total rows generated: {}'.format(len(sample_table)))
# Out:
# Total rows generated: 132
