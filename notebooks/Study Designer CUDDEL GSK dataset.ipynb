# %% [markdown]
# # GSK longitudinal dataset
#
# This notebook relies on the ISA-API to create the metadata for a
# dataset that was generated by GSK using an UPLC system and a hybrid
# electrospray LTQ/Orbitrap mass spectrometric platform (UPLC-LTQ/Orbitrap-MS)
# to determine the human metabolic profiles associated with food intake and exercise.

# %% [markdown]
# ## Setup
#
# As the first step, we import all the libraries we will be needing.

# %%
from ipywidgets import (RadioButtons, VBox, HBox, Layout, Label, Checkbox, Text, IntSlider)
from qgrid import show_grid
label_layout = Layout(width='100%')
from isatools.create.models import *
from isatools.model import Investigation
from isatools.isatab import dump_tables_to_dataframes as dumpdf
import qgrid
qgrid.nbinstall(overwrite=True)

# %% [markdown]
# ## Materials and Methods
#
# The study involved nine healthy male subjects provided plasma samples. They underwent 4
# regimens:
#
# 1. Regimen A: food+, exercise-
# 2. Regimen B: food-, exercise+
# 3. Regimen C: food+, exercise+
# 4. Regimen D: food-, exercise-
